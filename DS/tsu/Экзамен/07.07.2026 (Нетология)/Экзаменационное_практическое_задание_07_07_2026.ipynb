# %% [markdown]
# # Шаблон для выполнения экзаменационного практического задания (07.07.2026)

# %% [markdown]
# **Внимание!** Прежде, чем приступать к выполнению заданий, следует переименовать этот файл. В названии файла обязательно должна присутствовать фамилия студента – автора решения. **Безымянные работы проверяться не будут.**

# %% [markdown]
# Результат выполнения экзаменационного задания необходимо представить до конца строка выполнения практического занятия. Формат представления результата – ответ на задание в LMS в виде двух файлов:
#
# * ноутбук в формате **ipynb**, содержащий программный код, результаты его
# выполнения, а также все необходимые пояснения, выводы и комментарии
# (в текстовых ячейках);
#
# * файл в формате **html**, полученный путем экспорта ноутбука из п. 1.

# %% [markdown]
# Требования к решению:
#
# *  ответы в текстовых ячейках (не сгенерированный ИИ текст, а собственные рассуждения!) **обязательны для получения рейтинговых баллов**;
#
# * все предположения, обоснования и рекомендации должны быть даны для этого **конкретного набора данных**, а не в виде обобщенных формулировок;
#
# *  все выводимые на консоль значения должны быть **подписаны**;
#
# *  построенные графики должны быть хорошо читаемыми, иметь корректные названия и названия осей.

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Импортировать данные из файла, проверить корректность импорта и выполнить первичный анализ.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 1

# %% [markdown]
# **1.1)**	что представляет собой один объект в данном наборе данных

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.2)**	объем данных: количество объектов, доступных для построения модели

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.3)**	общее количество признаков объектов; в том числе количество числовых, порядковых и номинальных признаков (указать названия признаков)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.4)**	количество пропусков (если есть)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.5)** соответствуют ли типы данных и типы признаков; если нет, то для каких признаков

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.6)**	число классов и количество объектов по каждому классу; дать оценку сбалансированности классов

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.7)**	пригодность признаков для построения модели прогнозирования

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Выполнить исследование одномерных распределений количественных входных признаков (по заполненным значениям): найти описательные статистики и визуализировать распределения.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 2

# %% [markdown]
# **2.1)**	анализ характера распределения и однородности данных

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **2.2)** предположения о виде законов распределения признаков – **с пояснением**, на основании чего сделаны эти предположения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **2.3)**	рекомендации о возможности применения тех или иных методов корреляционного анализа – **с пояснением**, на основании чего сделаны эти рекомендации

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Выполнить исследование влияния входных категориальных признаков на прогнозируемый признак.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 3

# %% [markdown]
# **3.1)** предположения о наличии/отсутствии зависимости между категориальными входными признаками и прогнозируемым признаком – **с пояснением**, на основании чего сделаны эти предположения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **3.2)** выводы по проведенному анализу зависимостей между признаками

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Подготовить набор данных для построения модели логистической регрессии.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 4

# %% [markdown]
# **4.1)** **обоснование** выбранных методов предварительной обработки

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Создать и обучить модель логистической регрессии, изучить полученные результаты.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 5

# %% [markdown]
# **5.1)** выбранные гиперпараметры модели с **обоснованием** сделанного выбора

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **5.2)** предположение о наличии/отсутствии признаков переобучения модели – **с пояснением**, на основании чего сделано это предположение

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **5.3)** уравнение полученной модели прогнозирования

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **5.4)** интерпретация полученных значений метрик (какую информацию дают полученные числовые значения)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 6

# %% [markdown]
# Оценить качество прогнозов обученной модели на тестовой выборке.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ## Задание 7

# %% [markdown]
# Выполнить оценку качества прогнозирования полученной модели.

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Шаблон для выполнения заданий лабораторной работы 12. Вариант 2_1.

# %% [markdown]
# **Внимание!** Прежде, чем приступать к выполнению заданий, следует переименовать этот файл. В названии файла обязательно должна присутствовать фамилия студента – автора решения.
#
# **За безымянные работы рейтинговые баллы начислены не будут!**

# %% [markdown]
# Результат выполнения лабораторной работы необходимо представить до конца практического занятия. Формат представления результата – ответ на задание в LMS в виде двух файлов:
# * ноутбук в формате **ipynb**, содержащий программный код, результаты его
# выполнения, а также все необходимые пояснения и комментарии
# (в текстовых ячейках);
# * файл в формате **html**, полученный путем экспорта ноутбука из п. 1.
#
# Правильность работы представленного программного кода контролируется с помощью вопросов теста, ответы на которые также необходимо представить до конца практического занятия.
#
# Критерии оценивания выполненной работы:
# 1. Наличие и качество решений практических заданий (ответов в текстовых ячейках, программного кода и комментариев к нему).
#    *  Ответы в текстовых ячейках на поставленные вопросы **обязательны для получения баллов** за проверочный тест.
#    *  Все выводимые на консоль значения должны быть **подписаны**.
#    *  Построенные графики должны быть хорошо читаемыми, иметь корректные названия и названия осей.
#     *  На графике с несколькими цветами **обязательна легенда** для идентификации каждого цвета.
# 2. Количество правильных ответов на вопросы проверочного теста.

# %% [markdown]
# **Внимание:** самостоятельное и вдумчивое выполнение заданий повышает вероятность успешного прохождения итогового теста по теме 12 (будет проверяться, в том числе, понимание принципов работы с инструментарием и, в частности, умение понимать программный код).

# %%
# Этот код может понадобиться при выполнении задания 3
#import os
#os.environ['OMP_NUM_THREADS'] = '2'

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Выполнить импорт модуля *Pyplot* библиотеки *Matplotlib*, библиотеки *Seaborn* и библиотеки *NumPy*.

# %%
# Ваш код

# %% [markdown]
# Остальной необходимый для работы инструментарий подключать в тех кодовых ячейках, где он впервые используется.

# %% [markdown]
# Загрузить набор данных для анализа, выполнив код в ячейке ниже.
#
# **Пояснение**: этот код загружает [набор данных](https://allisonhorst.github.io/palmerpenguins/) о пингвинах с островов архипелага Палмер в Антарктиде. В работе будут использованы признаки:
#
# *  *bill_length_mm* – длина клюва (мм),
# *  *bill_depth_mm* – высота клюва (мм),
# *  *flipper_length_mm* – длина ласта (мм).

# %%
data = sns.load_dataset('penguins')
df21 = data.iloc[:, 2:5].dropna()

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вывести первые 7 строк фрейма **df21** для ознакомления.

# %%
# Ваш код

# %% [markdown]
# Определить количество объектов в наборе данных.

# %%
# Ваш код

# %% [markdown]
# Выполнить визуализацию набора данных, построив диаграммы рассеяния для всех попарных сочетаний трех признаков (проекции объектов трехмерного пространства признаков на плоскости соответствующих пар признаков).
#
# **Указание**. Разместить диаграммы на общей области построения, в один горизонтальный ряд. Имена признаков указать как названия осей.

# %%
# Ваш код

# %% [markdown]
# Если по двумерным проекциям затруднительно оценить форму и расположение кластеров, дополнительно можно построить 3D-визуализацию, раскомментировав и выполнив код в ячейке ниже.
#
# **Пояснение**. Построенную диаграмму можно вращать с помощью левой кнопки мыши, а масштабировать – с помощью колеса прокрутки.

# %%
#import plotly.express as px
#fig = px.scatter_3d(x=df21.iloc[:,0], y=df21.iloc[:,1], z=df21.iloc[:,2], labels={'x': df21.columns[0], 'y': df21.columns[1], 'z': df21.columns[2]})
#fig.update_layout(template='plotly_white')
#fig.update_traces(marker=dict(size=6, opacity=0.8))
#fig.show()

# %% [markdown]
# По результатам визуализации ответить на вопросы:
#
# *   насколько хорошо визуально разделимы кластеры?
#
# *   сколько кластеров можно выделить?
#
# *   какова форма наблюдаемых кластеров?
#
# *   наблюдается ли ли существенный дисбаланс по числу объектов между кластерами?
#
# *   есть ли кластеры различной плотности?
#
# *   присутствуют ли выбросы (точки, значительно удаленные от остальных объектов)?
#
# *   какая пара признаков обеспечивает наилучшую визуальную разделимость кластеров на диаграмме рассеяния?

# %% [markdown]
# __*Ваши ответы:*__
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *

# %% [markdown]
# Для каждого признака найти описательные статистики.

# %%
# Ваш код

# %% [markdown]
# Ответить на вопросы:
#
# *  требуется ли масштабирование признаков перед выполнением кластеризации? Обоснуйте ответ.
#
# *  если масштабирование необходимо, то какой метод масштабирования признаков следует применить? Обоснуйте выбор.

# %% [markdown]
# Создать и обучить обработчик для стандартизации признаков. Выполнить преобразование значений признаков в фрейме **df21**.

# %%
# Ваш код

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Обучить на масштабированных данных алгоритм кластеризации *K-means* для числа кластеров от 2 до 6 (включительно). Зафиксировать *random_state*, равный 21, остальные параметры оставить по умолчанию.
#
# Для каждой из обученных моделей:
#
# *  визуализировать результаты кластеризации в виде диаграмм рассеяния, отображая объекты разных кластеров различными цветами;
#
# *  вычислить значение силуэта выборки.
#
# **Указание**. При визуализации, как и в задании 2, использовать все попарные сочетания признаков. Для каждой модели разместить диаграммы на общей области построения в один ряд. Названия признаков указать по осям. Добавить легенду с отображением соответствия цветов и меток кластеров. В общем заголовке указать число кластеров и значение силуэта выборки, округлив его до 3 знаков после запятой.

# %%
# Ваш код
# При необходимости добавьте нужное количество кодовых ячеек

# %% [markdown]
# **Указание**. При выполнении кода может появиться предупреждение `UserWarning: KMeans is known to have a memory leak ...`, это означает наличие известной проблемы с управлением памятью в используемой библиотеке. Эта проблема не влияет на корректность результатов кластеризации, но может приводить к повышенному потреблению памяти и снижению производительности. Для устранения предупреждения вернитесь к первой кодовой ячейке, раскомментируйтей в ней код и перезапустите ядро (Restart Kernel).

# %% [markdown]
# Определить оптимальное число кластеров для алгоритма *K-means*. Привести обоснование на основе всех полученных результатов: учесть как визуальную оценку диаграмм рассеяния, так и значение метрики силуэта.

# %% [markdown]
# ***Ваши рассуждения и вывод***:

# %% [markdown]
# Оценить качество кластеризации для выбранного оптимального числа кластеров (с интерпретацией силуэта выборки – пояснить, что именно измеряет данная метрика).

# %% [markdown]
# ***Ваш ответ***:

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Ответить на вопросы:
#
# *  в чем геометрический смысл параметра *eps* алгоритма *DBSCAN*?
#
# *  что означает параметр *min_samples* алгоритма *DBSCAN*?

# %% [markdown]
# __*Ваши ответы:*__
#
# *
#
# *

# %% [markdown]
# Выполнить визуализацию масштабированных данных.
#
# **Указание**. Все требования к визуализации остаются такими же, что и в задании 2.

# %%
# Ваш код

# %% [markdown]
# Какие диапазоны значений параметров *eps* и *min_samples* алгоритма *DBSCAN* целесообразно исследовать при подборе модели? Обоснуйте выбор.

# %% [markdown]
# ***Ваши рассуждения и вывод***:

# %% [markdown]
# Обучить на масштабированных данных алгоритм кластеризации *DBSCAN* для всех комбинации значений параметра *eps* в диапазоне от 0.4 до 0.8 (включительно) с шагом 0.1 и параметра *min_samples* в диапазоне от 5 до 9 (включительно) с шагом 1.
#
# Для каждой из обученных моделей:
#
# *  визуализировать результаты кластеризации в виде диаграммы рассеяния, отображая объекты разных кластеров различными цветами;
#
# *  определить число шумовых точек;
#
# *  вычислить значение силуэта выборки.
#
# **Указание**. При визуализации использовать только ту пару признаков, которая в задании 2 была выбрана как обеспечивающая наилучшую визуальную разделимость кластеров. Разместить все построенные диаграммы на общей области построения (количество строк и столбцов должно соответствовать числу значений параметров). Названия признаков указать по осям. Добавить легенду с отображением соответствия цветов и меток кластеров. В заголовках диаграмм указать значения параметров, число шумовых точек и значение силуэта выборки, округленное до 3 знаков после запятой.

# %%
# Ваш код

# %% [markdown]
# Проанализировать полученные результаты и ответить на вопросы:
#
# *   как меняется результат кластеризации (число найденных кластеров и шумовых точек) при увеличении/уменьшении параметра *eps*?
#
# *   как меняется результат кластеризации при увеличении/уменьшении параметра *min_samples*?

# %% [markdown]
# __*Ваши ответы:*__
#
# *
#
# *

# %% [markdown]
# Выбрать лучшую модель среди обученных моделей *DBSCAN*. Привести обоснование на основе всех полученных результатов: учесть визуальную оценку диаграмм рассеяния, количество найденных шумовых точек, значение метрики силуэта.

# %% [markdown]
# ***Ваши рассуждения и вывод***:

# %% [markdown]
# ### Задание 5

# %% [markdown]
# Построить дендограмму для иерархической агломеративной кластеризации масштабированных данных. Использовать метод «дальнего соседа» (полной связи).

# %%
# Ваш код

# %% [markdown]
# Определить оптимальное число кластеров согласно дендограмме.

# %% [markdown]
# ***Ваш ответ***:

# %% [markdown]
# Для оптимального числа кластеров и нескольких ближайших к нему вариантов обучить на масштабированных данных алгоритм агломеративной кластеризации (способ определения расстояния между кластерами не менять) и вычислить силуэт выборки.

# %%
# Ваш код

# %% [markdown]
# Ответить на вопросы:
#
# *  какое число кластеров является оптимальным по метрике силуэта для агломеративной кластеризации?
#
# *  совпадает ли выбор оптимального числа кластеров  по дендограмме и по метрике силуэта для агломеративной кластеризации?
#
# *  если выбор различается, то чем это можно объяснить?

# %% [markdown]
# ***Ваши ответы:***
#
# *
#
# *
#
# *

# %% [markdown]
# ### Задание 6

# %% [markdown]
# Выполнить сравнительный анализ результатов работы трех алгоритмов кластеризации:
#
# *  алгоритма *K-means* с оптимальным числом кластеров, определенным в задании 3 (*random_state* не менять),
#
# *  алгоритма *DBSCAN* с оптимальными значениями параметров, определенными в задании 4,
#
# *  алгоритма агломеративной кластеризации с оптимальным по метрике силуэта числом кластеров (способ определения расстояния между кластерами не менять).
#
# Для каждого алгоритма:
#
# * создать и обучить модель на масштабированных данных;
#
# *  визуализировать результаты кластеризации в виде диаграмм рассеяния, отображая объекты разных кластеров различными цветами;
#
# *  вычислить значение силуэта выборки.
#
# **Указание**. При визуализации использовать все попарные сочетания признаков. Для каждой модели разместить диаграммы на общей области построения в один ряд. Названия признаков указать по осям. Добавить легенду с отображением соответствия цветов и меток кластеров. В общем заголовке указать название алгоритма, число кластеров и значение силуэта выборки, округлив его до 3 знаков после запятой.

# %%
# Ваш код
# При необходимости добавьте нужное количество кодовых ячеек

# %% [markdown]
# Дополнительно можно построить 3D-визуализацию результатов кластеризации для каждой из обученных моделей.
#
# **Указание**. Настройка цветов по меткам кластеров в методе *scatter_3d* выполняется с помощью параметра *color* (аналогично тому, как это выполняется в методе *scatter*).

# %% [markdown]
# Проанализировать полученные результаты и ответить на вопросы:
#
# * какой из алгоритмов показал наилучшее качество кластеризации? Выбор обосновать с учетом визуальной оценки диаграмм рассеяния и значения метрики силуэта.
#
# * насколько согласуются результаты алгоритмов по числу выделенных кластеров? Если есть различия, то чем они объясняются?
#
# * совпадает ли число кластеров, выделенных каждым алгоритмом, с результатом визуального анализа в задании 2? Если есть несовпадения, то чем они объясняются?

# %% [markdown]
# ***Ваши ответы:***
#
# *
#
# *
#
# *

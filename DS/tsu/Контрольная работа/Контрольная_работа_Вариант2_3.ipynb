# %% [markdown]
# ## Шаблон для выполнения заданий контрольной работы. Вариант 2_3.

# %% [markdown]
# **Внимание!** Прежде, чем приступать к выполнению заданий, следует переименовать этот файл. В названии файла обязательно должна присутствовать фамилия студента – автора решения. **За безымянные работы рейтинговые баллы начислены не будут!**

# %% [markdown]
# Результат выполнения контрольной работы необходимо представить до конца практического занятия. Формат представления результата – ответ на задание в LMS в виде двух файлов:
#
# * ноутбук в формате **ipynb**, содержащий программный код, результаты его
# выполнения, а также все необходимые пояснения, выводы и комментарии
# (в текстовых ячейках);
#
# * файл в формате **html**, полученный путем экспорта ноутбука из п. 1.

# %% [markdown]
# Требования к решению:
#
# *  ответы в текстовых ячейках (не сгенерированный ИИ текст, а собственные рассуждения!) **обязательны для получения рейтинговых баллов**;
#
# * все предположения, обоснования и рекомендации должны быть даны для этого **конкретного набора данных**, а не в виде обобщенных формулировок;
#
# *  все выводимые на консоль значения должны быть **подписаны**;
#
# *  построенные графики должны быть хорошо читаемыми, иметь корректные названия и названия осей.

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Импортировать данные из файла, проверить корректность импорта и выполнить первичный анализ.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 1

# %% [markdown]
# **1.1)**	что представляет собой один объект в данном наборе данных

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.2)**	объем данных: количество объектов, доступных для построения модели

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.3)**	общее количество признаков объектов; в том числе количество числовых, порядковых и номинальных признаков

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.4)**	количество пропусков (если есть)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.5)** соответствуют ли типы данных и типы признаков; если нет, то для каких признаков

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **1.6)**	пригодность признаков для построения модели прогнозирования

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Выполнить исследование одномерных распределений количественных входных признаков (по заполненным значениям), а также прогнозируемого признака: найти описательные статистики и визуализировать распределения.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 2

# %% [markdown]
# **2.1)**	анализ полученных описательных статистик (в том числе степень асимметричности признаков, «хвосты»)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **2.2)** анализ однородности данных (возможное наличие групп в данных, аномальных значений и др. особенностей)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **2.3)** предположения о виде законов распределения признаков – **с пояснением**, на основании чего сделаны эти предположения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **2.4)**	рекомендации о возможности применения тех или иных методов корреляционного анализа — **с пояснением**, на основании чего сделаны эти рекомендации

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Выполнить исследование (по заполненным значениям) на наличие связей между каждым из входных количественных признаков и прогнозируемым признаком, а также на наличие связей количественных входных признаков между собой.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 3

# %% [markdown]
# **3.1)** обоснование примененных методов корреляционного анализа (если не было сделано ранее)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **3.2)** анализ результатов применения методов корреляционного анализа

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **3.3)**	анализ полученных визуальных представлений и соотнесением с результатами корреляционного анализа

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **3.4)** выводы по проведенному анализу зависимостей между признаками

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Выполнить исследование распределений входных категориальных признаков, а также
# их влияния на прогнозируемую величину.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 4

# %% [markdown]
# **4.1)** анализ распределения категорий

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **4.2)** оценка правомерности применения критерия «хи-квадрат»

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **4.3)**	в случае правомерности  применения критерия «хи-квадрат» – выводы о наличии/отсутствии связей между признаками

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **4.4)** предположения о наличии/отсутствии зависимости между категориальными входными признаками и прогнозируемым признаком — **с пояснением**, на основании чего сделаны эти предположения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **4.5)** выводы по проведенному анализу зависимостей между признаками

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Для каждого признака, имеющего пропущенные значения, выполнить исследование, позволяющее обосновать выбор метода их заполнения и реализовать выбранную стратегию

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 5

# %% [markdown]
# **5.1)** пояснить, какие действия были выполнены в исследовании

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **5.2)** предположения о механизме формирования пропусков (можно ли считать случайным появление пропущенных значений) — **с пояснением**, на основании чего сделаны эти предположения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **5.3)** **обосновать** выбранные стратегии обработки пропущенных значений

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 6

# %% [markdown]
# Подготовить набор данных для построения моделей прогнозирования на основе решающих деревьев.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 6

# %% [markdown]
# **6.1)** **обоснование** выбранных методов (метода) преобразования категорий в числовые значения

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 7

# %% [markdown]
# Создать и обучить модели на основе решающих деревьев, изучить полученные результаты.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 7

# %% [markdown]
# **7.1)** интерпретация полученных значений метрик (какую информацию дают полученные числовые значения)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **7.2)** интерпретация предикатов разбиения для нескольких вершин дерева (не менее трех)

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 8

# %% [markdown]
# Оценить качество прогнозов всех обученных моделей на тестовой выборке.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ## Задание 9

# %% [markdown]
# Выполнить оценку качества прогнозирования всех полученных моделей.

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 9

# %% [markdown]
# **9.1)** вывод относительно обобщающей способности каждой из полученных моделей

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **9.2)** оценка качества прогнозов на основе визуального представления для лучшей из полученных моделей

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# ## Задание 10

# %% [markdown]
# Провести эксперименты по повышению качества прогнозирования.

# %%
# Ваш код

# %%
# Ваш код

# %%
# Ваш код
# Добавьте нужное количество кодовых ячеек

# %% [markdown]
# ### Комментарии и выводы по заданию 10

# %% [markdown]
# **10.1)** рекомендации по применению дополнительных мероприятий по повышению качества прогнозирования

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **10.2)** комментарии к выполняемым в ходе реализации предложенной стратегии действий
# Если стратегия реализована не была, то записать конкретные рекомендации по выбору тех или иных параметров, которые представляются вам наиболее перспективными

# %% [markdown]
# ***Ваш ответ:***

# %% [markdown]
# **10.3)** выводы по результатам реализованной стратегии
# Если стратегия реализована не была, то описать ожидаемые результаты применения предложенной стратегии

# %% [markdown]
# ***Ваш ответ:***

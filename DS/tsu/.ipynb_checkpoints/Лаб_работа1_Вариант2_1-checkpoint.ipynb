# %% [markdown]
# # Шаблон для выполнения заданий лабораторной работы 1. Вариант 2_1.

# %% [markdown]
# **Внимание!** Прежде, чем приступать к выполнению заданий, следует переименовать этот файл. В названии файла обязательно должна присутствовать фамилия студента - автора решения.
#
# **За безымянные работы рейтинговые баллы начислены не будут!**

# %% [markdown]
# Результат выполнения лабораторной работы необходимо представить до конца практического занятия. Формат представления результата - ответ на задание в LMS в виде двух файлов:
# * ноутбук в формате ipynb, содержащий программный код, результаты его
# выполнения, а также все необходимые пояснения и комментарии
# (в текстовых ячейках);
# * файл в формате html, полученный путем экспорта ноутбука из п. 1).
#
# Правильность работы представленного программного кода контролируется с помощью вопросов теста, ответы на которые также необходимо представить до конца практического занятия.
#
# Критерии оценивания выполненной работы:
# 1. Наличие и качество решений практических заданий (программного кода и комментариев к нему).
# 2. Количество правильных ответов на вопросы проверочного теста.

# %% [markdown]
# **Внимание:** самостоятельное и вдумчивое выполнение заданий повышает вероятность успешного прохождения итогового теста по теме 1 на следующей учебной встрече (будет проверяться понимание работы принципов работы с инструментарием и, в частности, умение понимать программный код).

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Выполнить импорт библиотеки NumPy и модуля Pyplot библиотеки Matplotlib.
#
# Подключить "построение графиков online"

# %%
# Ваш код

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Создать список flist, выполнив код в ячейке ниже

# %%
np.random.seed(5)
flist = [[round(np.random.rand(), 3) for j in np.linspace(0.5, 10, 20)] for i in range(8)]

# %% [markdown]
# Преобразовать список flist в массив farray

# %%
# Раскомментировать строку ниже и дописать определение массива

#  farray =

# %% [markdown]
# Вывести размерность полученного массива (число строк и столбцов)

# %%
# Ваш код

# %% [markdown]
# Вывести элемент, стоящий во второй (по порядку, а не по индексу) строке и пятом (по порядку) столбце массива farray

# %%
# Ваш код

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Создать массив frac, содержащий значения функции $$f(x) = \frac {1}{x^2+1} $$ для значений $x$, принадлежащих отрезку [-5; 7] с шагом 0.5.

# %%
# Ваш код

# %% [markdown]
# Вывести значение frac[13], округленное до 3 знаков после запятой.

# %%
# Ваш код

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Создать массивы Vect и Matr, выполнив код в ячейке ниже

# %%
np.random.seed(5)
Vect = np.random.rand(21)
Matr = np.random.rand(3, 4)

# %% [markdown]
# Вывести элементы массивов (для контроля)

# %%
# Ваш код

# %% [markdown]
# Преобразовать размерность массива Vect так, чтобы этот массив состоял из 3 столбцов.

# %%
# Ваш код

# %% [markdown]
# Найти матричное произведение Vect и Matr, результат сохранить в массиве VM

# %%
# Ваш код

# %% [markdown]
# Вывести последний элемент предпоследней строки матрицы VM. Значение округлить до 2 знаков после запятой.

# %%
# Ваш код

# %% [markdown]
# ### Задание 5

# %% [markdown]
# Для матрицы VM, созданной в задании 4: сохранить в массиве subVM элементы строк VM с нечетными индексами, исключая элементы первого столбца.
#
# Операцию выполнить, используя инструменты работы с массивами (без применения циклов и списков)

# %%
# Ваш код

# %% [markdown]
# Преобразовать полученный массив subVM в одномерный вектор vect_VM и вывести элемент vect_VM[6] с точностью до 2 знаков после запятой.

# %%
# Ваш код

# %% [markdown]
# ### Задание 6

# %% [markdown]
# К матрице subVM, созданной в задании 5, добавить столбец, состоящий из единиц. Добавляемый столбец вставить в конце (последним столбцом).
#
# Результат сохранить в массиве subVM1.

# %%
# Ваш код

# %% [markdown]
# Вывести размерность массива subVM1.

# %%
# Ваш код

# %% [markdown]
# ### Задание 7

# %% [markdown]
# К матрице subVM1, созданной в задании 6, добавить строку, содержащую минимальные элементы соответствующих столбцов матрицы subVM1. Добавляемую строку встравить в начале (первой строкой).
#
# Результат сохранить в массиве VMmin.

# %%
# Ваш код

# %% [markdown]
# Вывести элемент матрицы VMmin, стоящий в первой (по порядку, а не по индексу) строке и во втором (по порядку) столбце. Значение округлить до 3 знаков после запятой.

# %%
# Ваш код

# %% [markdown]
# Вычислить определитель матрицы VMmin.
#
# Вывести его значение с точностью до 4 знаков после запятой

# %%
# Ваш код

# %% [markdown]
# ### Задание 8

# %% [markdown]
# Построить график функции  $$f(x) = \frac{(x-2)^2}{x+1}$$ на отрезке [-5, -3.5] c шагом, равным 0.05.
#
# Выставить метки по осям: по оси абсцисс с шагом 0.25; по оси ординат - с шагом 0.05.

# %%
# Ваш код

# %% [markdown]
# Определить по графику абсциссу точки локального максимума функции
